# %% [markdown]
# Loading the Fashion-MNIST data.

# %%
import gzip
import numpy as np
import matplotlib.pyplot as plt

def load_data(filename, dims):
    with gzip.open(filename, "rb") as infile:
        # consume magic number
        infile.read(4)
        # consume dimensions data
        infile.read(4 * len(dims))

        return np.frombuffer(infile.read(np.prod(dims)), dtype=np.uint8).reshape(dims)

# training data
train_images = load_data("data/train-images-idx3-ubyte.gz", [60000, 28, 28])
train_labels = load_data("data/train-labels-idx1-ubyte.gz", [60000])

# testing data
test_images = load_data("data/t10k-images-idx3-ubyte.gz", [10000, 28, 28])
test_labels = load_data("data/t10k-labels-idx1-ubyte.gz", [10000])

# %% [markdown]
# Converting the images to floating point data and rescaling them between 0 and 1. Creating one-hot vectors from the labels.

# %%
train_x = train_images.astype(np.float) / 255
train_y = np.zeros((60000, 10))
train_y[np.arange(60000),train_labels] = 1

test_x = test_images.astype(np.float) / 255
test_y = np.zeros((10000, 10))
test_y[np.arange(10000),test_labels] = 1

# %% [markdown]
# Creating 2D UMAP and PCA embeddings for visualizing the data.

# %%
import os
import pickle
from umap import UMAP
from sklearn.decomposition import PCA


def create_embeddings(data, ignore_cache=False):
    umap_dir = "cache/umap.pickle"
    pca_dir = "cache/pca.pickle"

    if not os.path.isfile(umap_dir) or ignore_cache:
        umap_reducer = UMAP(random_state=42).fit(data)
        pickle.dump(umap_reducer, open(umap_dir, "wb"))
    else:
        umap_reducer = pickle.load(open(umap_dir, "rb"))

    if not os.path.isfile(pca_dir) or ignore_cache:
        pca_reducer = PCA(n_components=2, random_state=42).fit(data)
        pickle.dump(pca_reducer, open(pca_dir, "wb"))
    else:
        pca_reducer = pickle.load(open(pca_dir, "rb"))
        
    return umap_reducer, pca_reducer


umap_reducer, pca_reducer = create_embeddings(train_x.reshape(-1, 784), ignore_cache=False)
umap_data = umap_reducer.transform(train_x.reshape(-1, 784))
pca_data = pca_reducer.transform(train_x.reshape(-1, 784))


def plot_embeddings():
    fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
    axes[0].scatter(umap_data[:,0], umap_data[:,1], s=1, c=train_labels, cmap='Spectral')
    axes[0].set_title("UMAP Embedding")

    axes[1].scatter(pca_data[:,0], pca_data[:,1], s=1, c=train_labels, cmap='Spectral')
    axes[1].set_title("PCA Embedding")
    plt.setp(axes, xticks=[], yticks=[])
    plt.tight_layout()
    
plot_embeddings()

# %% [markdown]
# Helper function for plotting the movement of clusters during training.

# %%
def plot_cluster_movement(ax, data, init, current):
    change = current - init
    
    ax.scatter(data[:,0], data[:,1], s=1, c=train_labels, cmap='Spectral')
    s1 = ax.scatter(init[:,0], init[:,1], s=100, c="k", marker="^")
    s2 = ax.scatter(current[:,0], current[:,1], s=100, c="r", marker="^")
    
    for i in range(change.shape[0]):
        ax.arrow(init[i,0], init[i,1], change[i,0], change[i,1])
    ax.legend([s1, s2], ["Before Training", "After Training"])

# %% [markdown]
# Training the model with a random initialization. Plot the cluster movement over the course of training. Plot the training and test accuracy over the course of training.

# %%
import keras
import keras.layers as layers
import keras.models as models
import keras.backend as K
from model import GaussMembership, normalized_product_fn


def train_random_initialization():
    # create the model
    model = keras.Sequential([
        layers.Reshape((784,), input_shape=(28,28)),
        GaussMembership(10),
        layers.Lambda(lambda x: normalized_product_fn(x)),
        layers.Dense(10, activation="sigmoid"),])
    
    # set weights randomly
    model.layers[1].set_weights((
        # multiplying the by the mean is a way to ensure that the centers occupy the same subset of the
        # feature space as the input data
        np.random.normal(1., 0.1, size=(10,784)) * np.mean(train_x.reshape(-1, 784), axis=0, keepdims=True),
        np.random.normal(1., 0.1, size=(10,784))))
    
    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics=[keras.metrics.categorical_accuracy])
    
    init_mu = model.layers[1].get_weights()[0]

    # train the model
    history = model.fit(
        x=train_x,
        y=train_y,
        batch_size=64,
        epochs=50,
        validation_data=(test_x, test_y),
        verbose=1,
        shuffle=True)
    
    final_mu, final_sigma = model.layers[1].get_weights()
    
    # plot the cluster movement
    fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
    axes[0].set_title("Cluster Movement (UMAP)")
    plot_cluster_movement(
        axes[0], umap_data,
        umap_reducer.transform(init_mu), 
        umap_reducer.transform(final_mu))

    axes[1].set_title("Cluster Movement (PCA)")
    plot_cluster_movement(
        axes[1], pca_data,
        pca_reducer.transform(init_mu), 
        pca_reducer.transform(final_mu))
    
    # plot the loss and accuracy
    fig, axes = plt.subplots(1, 2, figsize=(8, 4), squeeze=True)
    axes[0].set_title("Loss")
    axes[0].plot(history.history["loss"], c="b")
    axes[0].plot(history.history["val_loss"], c="r")

    axes[1].set_title("Accuracy")
    #axes[1].set_ylim((0.8, 1))
    axes[1].plot(history.history["categorical_accuracy"], c="b")
    axes[1].plot(history.history["val_categorical_accuracy"], c="r")
    
    # plot mean firing strength for class
    fstrength_fn = K.function(model.inputs, [model.layers[2].output])
    fig, axes = plt.subplots(10, 1, squeeze=True, figsize=(8,8), sharex=True)
    for i in range(10):
        fstrength = fstrength_fn([train_x[train_labels == i]])[0]
        axes[i].set_title("Class {}".format(i))
        axes[i].bar(np.arange(10), np.mean(fstrength, axis=0))
        
    plt.setp(axes, xticks=np.arange(10), yticks=[0,1])
    plt.tight_layout()
    
    # plot weights and bias
    kernel, bias = model.layers[3].get_weights()
    fig, (ax0, ax1) = plt.subplots(
        1, 2, sharey=True, squeeze=True, gridspec_kw={'width_ratios':[9, 1]})

    im0 = ax0.imshow(kernel.T, cmap="bwr")
    ax0.set_title("Weights")
    ax0.set_ylabel("Class")
    ax0.set_xlabel("Rule")
    ax0.set_yticks(np.arange(10))
    ax0.set_xticks(np.arange(10))

    ax1.imshow(bias.reshape(10,1), cmap="bwr", vmin=np.min(kernel), vmax=np.max(kernel))
    ax1.set_title("Bias")
    ax1.set_xticks([])

    plt.tight_layout()
    fig.colorbar(im0, ax=[ax0, ax1])
    
    # plot mu and sigma parameters
    fig, axes = plt.subplots(2, 10, figsize=(16,4))
    for i in range(10):
        axes[0][i].imshow(final_mu[i,:].reshape(28, 28), cmap="Greys", interpolation="none")
        axes[1][i].imshow(final_sigma[i,:].reshape(28, 28), cmap="Greys", interpolation="none")

    plt.setp(axes, xticks=[], yticks=[], frame_on=False)
    plt.tight_layout(h_pad=0, w_pad=0)
    
    
train_random_initialization()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0217 20:03:51.888733 139892860090176 deprecation.py:323] From /home/ryan-desktop/anaconda3/envs/keras/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.3121 - categorical_accuracy: 0.4550 - val_loss: 0.2391 - val_categorical_accuracy: 0.7521
# Epoch 2/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.2090 - categorical_accuracy: 0.7889 - val_loss: 0.1823 - val_categorical_accuracy: 0.8221
# Epoch 3/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.1625 - categorical_accuracy: 0.8434 - val_loss: 0.1455 - val_categorical_accuracy: 0.8583
# Epoch 4/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.1314 - categorical_accuracy: 0.8682 - val_loss: 0.1202 - val_categorical_accuracy: 0.8761
# Epoch 5/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.1099 - categorical_accuracy: 0.8847 - val_loss: 0.1026 - val_categorical_accuracy: 0.8917
# Epoch 6/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0951 - categorical_accuracy: 0.8957 - val_loss: 0.0902 - val_categorical_accuracy: 0.8999
# Epoch 7/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0849 - categorical_accuracy: 0.9037 - val_loss: 0.0823 - val_categorical_accuracy: 0.9039
# Epoch 8/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0773 - categorical_accuracy: 0.9089 - val_loss: 0.0756 - val_categorical_accuracy: 0.9093
# Epoch 9/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0718 - categorical_accuracy: 0.9134 - val_loss: 0.0723 - val_categorical_accuracy: 0.9112
# Epoch 10/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0675 - categorical_accuracy: 0.9171 - val_loss: 0.0686 - val_categorical_accuracy: 0.9147
# Epoch 11/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0642 - categorical_accuracy: 0.9200 - val_loss: 0.0663 - val_categorical_accuracy: 0.9176
# Epoch 12/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0613 - categorical_accuracy: 0.9226 - val_loss: 0.0629 - val_categorical_accuracy: 0.9224
# Epoch 13/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0594 - categorical_accuracy: 0.9247 - val_loss: 0.0619 - val_categorical_accuracy: 0.9244
# Epoch 14/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0574 - categorical_accuracy: 0.9267 - val_loss: 0.0595 - val_categorical_accuracy: 0.9229
# Epoch 15/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0558 - categorical_accuracy: 0.9279 - val_loss: 0.0593 - val_categorical_accuracy: 0.9239
# Epoch 16/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0546 - categorical_accuracy: 0.9297 - val_loss: 0.0578 - val_categorical_accuracy: 0.9269
# Epoch 17/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0534 - categorical_accuracy: 0.9304 - val_loss: 0.0570 - val_categorical_accuracy: 0.9264
# Epoch 18/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0522 - categorical_accuracy: 0.9326 - val_loss: 0.0575 - val_categorical_accuracy: 0.9281
# Epoch 19/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0512 - categorical_accuracy: 0.9333 - val_loss: 0.0558 - val_categorical_accuracy: 0.9300
# Epoch 20/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0503 - categorical_accuracy: 0.9343 - val_loss: 0.0560 - val_categorical_accuracy: 0.9278
# Epoch 21/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0493 - categorical_accuracy: 0.9355 - val_loss: 0.0550 - val_categorical_accuracy: 0.9279
# Epoch 22/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0485 - categorical_accuracy: 0.9357 - val_loss: 0.0540 - val_categorical_accuracy: 0.9324
# Epoch 23/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0479 - categorical_accuracy: 0.9373 - val_loss: 0.0530 - val_categorical_accuracy: 0.9343
# Epoch 24/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0471 - categorical_accuracy: 0.9384 - val_loss: 0.0520 - val_categorical_accuracy: 0.9316
# Epoch 25/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0465 - categorical_accuracy: 0.9386 - val_loss: 0.0539 - val_categorical_accuracy: 0.9301
# Epoch 26/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0456 - categorical_accuracy: 0.9402 - val_loss: 0.0514 - val_categorical_accuracy: 0.9345
# Epoch 27/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0451 - categorical_accuracy: 0.9406 - val_loss: 0.0511 - val_categorical_accuracy: 0.9334
# Epoch 28/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0447 - categorical_accuracy: 0.9411 - val_loss: 0.0510 - val_categorical_accuracy: 0.9321
# Epoch 29/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0442 - categorical_accuracy: 0.9416 - val_loss: 0.0511 - val_categorical_accuracy: 0.9338
# Epoch 30/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0437 - categorical_accuracy: 0.9418 - val_loss: 0.0510 - val_categorical_accuracy: 0.9324
# Epoch 31/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0432 - categorical_accuracy: 0.9422 - val_loss: 0.0504 - val_categorical_accuracy: 0.9332
# Epoch 32/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0427 - categorical_accuracy: 0.9426 - val_loss: 0.0495 - val_categorical_accuracy: 0.9350
# Epoch 33/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0422 - categorical_accuracy: 0.9440 - val_loss: 0.0505 - val_categorical_accuracy: 0.9318
# Epoch 34/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0420 - categorical_accuracy: 0.9435 - val_loss: 0.0494 - val_categorical_accuracy: 0.9342
# Epoch 35/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0415 - categorical_accuracy: 0.9448 - val_loss: 0.0496 - val_categorical_accuracy: 0.9333
# Epoch 36/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0410 - categorical_accuracy: 0.9447 - val_loss: 0.0494 - val_categorical_accuracy: 0.9347
# Epoch 37/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0407 - categorical_accuracy: 0.9448 - val_loss: 0.0491 - val_categorical_accuracy: 0.9358
# Epoch 38/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0403 - categorical_accuracy: 0.9458 - val_loss: 0.0482 - val_categorical_accuracy: 0.9355
# Epoch 39/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0399 - categorical_accuracy: 0.9463 - val_loss: 0.0494 - val_categorical_accuracy: 0.9318
# Epoch 40/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0397 - categorical_accuracy: 0.9462 - val_loss: 0.0479 - val_categorical_accuracy: 0.9352
# Epoch 41/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0395 - categorical_accuracy: 0.9472 - val_loss: 0.0485 - val_categorical_accuracy: 0.9356
# Epoch 42/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0391 - categorical_accuracy: 0.9469 - val_loss: 0.0483 - val_categorical_accuracy: 0.9331
# Epoch 43/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0385 - categorical_accuracy: 0.9479 - val_loss: 0.0484 - val_categorical_accuracy: 0.9327
# Epoch 44/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0385 - categorical_accuracy: 0.9475 - val_loss: 0.0487 - val_categorical_accuracy: 0.9327
# Epoch 45/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0381 - categorical_accuracy: 0.9485 - val_loss: 0.0475 - val_categorical_accuracy: 0.9347
# Epoch 46/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0380 - categorical_accuracy: 0.9480 - val_loss: 0.0473 - val_categorical_accuracy: 0.9381
# Epoch 47/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0377 - categorical_accuracy: 0.9488 - val_loss: 0.0470 - val_categorical_accuracy: 0.9361
# Epoch 48/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0374 - categorical_accuracy: 0.9487 - val_loss: 0.0478 - val_categorical_accuracy: 0.9352
# Epoch 49/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0374 - categorical_accuracy: 0.9493 - val_loss: 0.0475 - val_categorical_accuracy: 0.9355
# Epoch 50/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0370 - categorical_accuracy: 0.9500 - val_loss: 0.0471 - val_categorical_accuracy: 0.9350

# %% [markdown]
# The clusters still do not appear to fit the data in the projections. This has happened in all experiments despite the network being able to fit the data quite well.
#
# Inspecting the parameters shows that the network has not learned the classes in the way that was expected. The parameters appear as random shapes when plotted as images. This is why UMAP can't project them properly (they are likely not on the manifold).

# %% [markdown]
# Next, the model is trained using the FCM initialization.

# %%
import skfuzzy as skf


def train_fcm_initialization():
    # create the model
    model = keras.Sequential([
        layers.Reshape((784,), input_shape=(28,28)),
        GaussMembership(10),
        layers.Lambda(lambda x: normalized_product_fn(x)),
        layers.Dense(10, activation="sigmoid"),])
    
    init_mu, memberships, u0, d, jm, p, fpc = skf.cmeans(
        train_x.reshape(-1, 784).T, 10, 1.1, 1e-8, 1000, seed=0)
    
    # set weights with fcm
    model.layers[1].set_weights((
        init_mu,
        np.random.normal(1., 0.1, size=(10,784))))
    
    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics=[keras.metrics.categorical_accuracy])

    # train the model
    history = model.fit(
        x=train_x,
        y=train_y,
        batch_size=64,
        epochs=50,
        validation_data=(test_x, test_y),
        verbose=1,
        shuffle=True)
    
    final_mu, final_sigma = model.layers[1].get_weights()
    
    # plot the cluster movement
    fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
    axes[0].set_title("Cluster Movement (UMAP)")
    plot_cluster_movement(
        axes[0], umap_data,
        umap_reducer.transform(init_mu), 
        umap_reducer.transform(final_mu))

    axes[1].set_title("Cluster Movement (PCA)")
    plot_cluster_movement(
        axes[1], pca_data,
        pca_reducer.transform(init_mu), 
        pca_reducer.transform(final_mu))
    
    # plot the loss and accuracy
    fig, axes = plt.subplots(1, 2, figsize=(8, 4), squeeze=True)
    axes[0].set_title("Loss")
    axes[0].plot(history.history["loss"], c="b")
    axes[0].plot(history.history["val_loss"], c="r")

    axes[1].set_title("Accuracy")
    #axes[1].set_ylim((0.8, 1))
    axes[1].plot(history.history["categorical_accuracy"], c="b")
    axes[1].plot(history.history["val_categorical_accuracy"], c="r")
    
        # plot mean firing strength for class
    fstrength_fn = K.function(model.inputs, [model.layers[2].output])
    fig, axes = plt.subplots(10, 1, squeeze=True, figsize=(8,8), sharex=True)
    for i in range(10):
        fstrength = fstrength_fn([train_x[train_labels == i]])[0]
        axes[i].set_title("Class {}".format(i))
        axes[i].bar(np.arange(10), np.mean(fstrength, axis=0))
        
    plt.setp(axes, xticks=np.arange(10), yticks=[0,1])
    plt.tight_layout()
    
    # plot weights and bias
    kernel, bias = model.layers[3].get_weights()
    fig, (ax0, ax1) = plt.subplots(
        1, 2, sharey=True, squeeze=True, gridspec_kw={'width_ratios':[9, 1]})

    im0 = ax0.imshow(kernel.T, cmap="bwr")
    ax0.set_title("Weights")
    ax0.set_ylabel("Class")
    ax0.set_xlabel("Rule")
    ax0.set_yticks(np.arange(10))
    ax0.set_xticks(np.arange(10))

    ax1.imshow(bias.reshape(10,1), cmap="bwr", vmin=np.min(kernel), vmax=np.max(kernel))
    ax1.set_title("Bias")
    ax1.set_xticks([])

    plt.tight_layout()
    fig.colorbar(im0, ax=[ax0, ax1])
    
    # plot mu and sigma parameters
    fig, axes = plt.subplots(2, 10, figsize=(16,3))
    for i in range(10):
        axes[0][i].imshow(final_mu[i,:].reshape(28, 28), cmap="Greys", interpolation="none")
        axes[1][i].imshow(final_sigma[i,:].reshape(28, 28), cmap="Greys", interpolation="none")

    plt.setp(axes, xticks=[], yticks=[], frame_on=False)
    plt.tight_layout(h_pad=0, w_pad=0)
    
    
train_fcm_initialization()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.4213 - categorical_accuracy: 0.2729 - val_loss: 0.2774 - val_categorical_accuracy: 0.4920
# Epoch 2/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.2280 - categorical_accuracy: 0.6927 - val_loss: 0.1891 - val_categorical_accuracy: 0.7692
# Epoch 3/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1687 - categorical_accuracy: 0.8170 - val_loss: 0.1493 - val_categorical_accuracy: 0.8624
# Epoch 4/50
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.1370 - categorical_accuracy: 0.8628 - val_loss: 0.1244 - val_categorical_accuracy: 0.8799
# Epoch 5/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.1170 - categorical_accuracy: 0.8796 - val_loss: 0.1090 - val_categorical_accuracy: 0.8897
# Epoch 6/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.1037 - categorical_accuracy: 0.8883 - val_loss: 0.0985 - val_categorical_accuracy: 0.8946
# Epoch 7/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0942 - categorical_accuracy: 0.8939 - val_loss: 0.0905 - val_categorical_accuracy: 0.8980
# Epoch 8/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0876 - categorical_accuracy: 0.8989 - val_loss: 0.0865 - val_categorical_accuracy: 0.8984
# Epoch 9/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0826 - categorical_accuracy: 0.9021 - val_loss: 0.0831 - val_categorical_accuracy: 0.9022
# Epoch 10/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0788 - categorical_accuracy: 0.9029 - val_loss: 0.0788 - val_categorical_accuracy: 0.9045
# Epoch 11/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0755 - categorical_accuracy: 0.9069 - val_loss: 0.0776 - val_categorical_accuracy: 0.9039
# Epoch 12/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0729 - categorical_accuracy: 0.9092 - val_loss: 0.0753 - val_categorical_accuracy: 0.9042
# Epoch 13/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0706 - categorical_accuracy: 0.9108 - val_loss: 0.0740 - val_categorical_accuracy: 0.9039
# Epoch 14/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0685 - categorical_accuracy: 0.9135 - val_loss: 0.0723 - val_categorical_accuracy: 0.9085
# Epoch 15/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0667 - categorical_accuracy: 0.9154 - val_loss: 0.0701 - val_categorical_accuracy: 0.9082
# Epoch 16/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0651 - categorical_accuracy: 0.9171 - val_loss: 0.0690 - val_categorical_accuracy: 0.9121
# Epoch 17/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0633 - categorical_accuracy: 0.9193 - val_loss: 0.0675 - val_categorical_accuracy: 0.9096
# Epoch 18/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0621 - categorical_accuracy: 0.9206 - val_loss: 0.0669 - val_categorical_accuracy: 0.9089
# Epoch 19/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0604 - categorical_accuracy: 0.9218 - val_loss: 0.0664 - val_categorical_accuracy: 0.9116
# Epoch 20/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0592 - categorical_accuracy: 0.9244 - val_loss: 0.0648 - val_categorical_accuracy: 0.9121
# Epoch 21/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0580 - categorical_accuracy: 0.9249 - val_loss: 0.0637 - val_categorical_accuracy: 0.9139
# Epoch 22/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0571 - categorical_accuracy: 0.9256 - val_loss: 0.0644 - val_categorical_accuracy: 0.9106
# Epoch 23/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0560 - categorical_accuracy: 0.9273 - val_loss: 0.0621 - val_categorical_accuracy: 0.9154
# Epoch 24/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0550 - categorical_accuracy: 0.9286 - val_loss: 0.0617 - val_categorical_accuracy: 0.9146
# Epoch 25/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0544 - categorical_accuracy: 0.9281 - val_loss: 0.0628 - val_categorical_accuracy: 0.9133
# Epoch 26/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0536 - categorical_accuracy: 0.9289 - val_loss: 0.0614 - val_categorical_accuracy: 0.9167
# Epoch 27/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0529 - categorical_accuracy: 0.9297 - val_loss: 0.0608 - val_categorical_accuracy: 0.9159
# Epoch 28/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0524 - categorical_accuracy: 0.9301 - val_loss: 0.0612 - val_categorical_accuracy: 0.9148
# Epoch 29/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0518 - categorical_accuracy: 0.9311 - val_loss: 0.0601 - val_categorical_accuracy: 0.9160
# Epoch 30/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0512 - categorical_accuracy: 0.9312 - val_loss: 0.0598 - val_categorical_accuracy: 0.9159
# Epoch 31/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0506 - categorical_accuracy: 0.9322 - val_loss: 0.0606 - val_categorical_accuracy: 0.9147
# Epoch 32/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0503 - categorical_accuracy: 0.9318 - val_loss: 0.0597 - val_categorical_accuracy: 0.9138
# Epoch 33/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0495 - categorical_accuracy: 0.9336 - val_loss: 0.0601 - val_categorical_accuracy: 0.9148
# Epoch 34/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0491 - categorical_accuracy: 0.9338 - val_loss: 0.0598 - val_categorical_accuracy: 0.9145
# Epoch 35/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0487 - categorical_accuracy: 0.9349 - val_loss: 0.0605 - val_categorical_accuracy: 0.9137
# Epoch 36/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0484 - categorical_accuracy: 0.9344 - val_loss: 0.0595 - val_categorical_accuracy: 0.9149
# Epoch 37/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0478 - categorical_accuracy: 0.9358 - val_loss: 0.0584 - val_categorical_accuracy: 0.9188
# Epoch 38/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0473 - categorical_accuracy: 0.9366 - val_loss: 0.0566 - val_categorical_accuracy: 0.9204
# Epoch 39/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0469 - categorical_accuracy: 0.9367 - val_loss: 0.0568 - val_categorical_accuracy: 0.9212
# Epoch 40/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0467 - categorical_accuracy: 0.9369 - val_loss: 0.0556 - val_categorical_accuracy: 0.9218
# Epoch 41/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0461 - categorical_accuracy: 0.9377 - val_loss: 0.0580 - val_categorical_accuracy: 0.9181
# Epoch 42/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0456 - categorical_accuracy: 0.9392 - val_loss: 0.0569 - val_categorical_accuracy: 0.9201
# Epoch 43/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0455 - categorical_accuracy: 0.9391 - val_loss: 0.0558 - val_categorical_accuracy: 0.9198
# Epoch 44/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0451 - categorical_accuracy: 0.9389 - val_loss: 0.0555 - val_categorical_accuracy: 0.9218
# Epoch 45/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0447 - categorical_accuracy: 0.9395 - val_loss: 0.0546 - val_categorical_accuracy: 0.9217
# Epoch 46/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0445 - categorical_accuracy: 0.9403 - val_loss: 0.0553 - val_categorical_accuracy: 0.9205
# Epoch 47/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0443 - categorical_accuracy: 0.9402 - val_loss: 0.0538 - val_categorical_accuracy: 0.9245
# Epoch 48/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0439 - categorical_accuracy: 0.9406 - val_loss: 0.0554 - val_categorical_accuracy: 0.9208
# Epoch 49/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0436 - categorical_accuracy: 0.9407 - val_loss: 0.0568 - val_categorical_accuracy: 0.9210
# Epoch 50/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0431 - categorical_accuracy: 0.9411 - val_loss: 0.0545 - val_categorical_accuracy: 0.9257

# %% [markdown]
# When initialized using FCM, the clusters start in more appropriate locations but move towards the center of dataset. Even though the clusters appear to be in better locations, the performance slightly worse than the random initialization.
#
# Additionally, the parameters form slightly better images but for most part still appear as random blobs.

# %% [markdown]
# The next step is to create a convolutional neural network for Fashion MNIST.

# %%
def train_cnn():
    model = keras.Sequential([
        layers.Reshape((28,28,1), input_shape=(28,28)),
        layers.Conv2D(16, (3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(32, (3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(64, (3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ])
    
    model.compile(
        optimizer="adam",
        loss="categorical_crossentropy",
        metrics=[keras.metrics.categorical_accuracy])

    # train the model
    history = model.fit(
        x=train_x,
        y=train_y,
        batch_size=64,
        epochs=20,
        validation_data=(test_x, test_y),
        verbose=1,
        shuffle=True)
    
    # plot the loss and accuracy
    fig, axes = plt.subplots(1, 2, figsize=(8, 4), squeeze=True)
    axes[0].set_title("Loss")
    axes[0].plot(history.history["loss"], c="b")
    axes[0].plot(history.history["val_loss"], c="r")

    axes[1].set_title("Accuracy")
    axes[1].plot(history.history["categorical_accuracy"], c="b")
    axes[1].plot(history.history["val_categorical_accuracy"], c="r")


train_cnn()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.2070 - categorical_accuracy: 0.9375 - val_loss: 0.0841 - val_categorical_accuracy: 0.9719
# Epoch 2/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0637 - categorical_accuracy: 0.9806 - val_loss: 0.0481 - val_categorical_accuracy: 0.9836
# Epoch 3/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0447 - categorical_accuracy: 0.9861 - val_loss: 0.0391 - val_categorical_accuracy: 0.9870
# Epoch 4/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0311 - categorical_accuracy: 0.9905 - val_loss: 0.0403 - val_categorical_accuracy: 0.9883
# Epoch 5/20
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.0253 - categorical_accuracy: 0.9920 - val_loss: 0.0461 - val_categorical_accuracy: 0.9861
# Epoch 6/20
# 60000/60000 [==============================] - 4s 64us/step - loss: 0.0199 - categorical_accuracy: 0.9938 - val_loss: 0.0389 - val_categorical_accuracy: 0.9868
# Epoch 7/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0152 - categorical_accuracy: 0.9952 - val_loss: 0.0374 - val_categorical_accuracy: 0.9881
# Epoch 8/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0145 - categorical_accuracy: 0.9954 - val_loss: 0.0404 - val_categorical_accuracy: 0.9870
# Epoch 9/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0114 - categorical_accuracy: 0.9960 - val_loss: 0.0517 - val_categorical_accuracy: 0.9874
# Epoch 10/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0112 - categorical_accuracy: 0.9962 - val_loss: 0.0464 - val_categorical_accuracy: 0.9879
# Epoch 11/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0083 - categorical_accuracy: 0.9971 - val_loss: 0.0388 - val_categorical_accuracy: 0.9891
# Epoch 12/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0076 - categorical_accuracy: 0.9975 - val_loss: 0.0480 - val_categorical_accuracy: 0.9891
# Epoch 13/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0077 - categorical_accuracy: 0.9979 - val_loss: 0.0424 - val_categorical_accuracy: 0.9889
# Epoch 14/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0095 - categorical_accuracy: 0.9968 - val_loss: 0.0380 - val_categorical_accuracy: 0.9898
# Epoch 15/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0049 - categorical_accuracy: 0.9984 - val_loss: 0.0427 - val_categorical_accuracy: 0.9902
# Epoch 16/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0062 - categorical_accuracy: 0.9981 - val_loss: 0.0482 - val_categorical_accuracy: 0.9882
# Epoch 17/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0066 - categorical_accuracy: 0.9981 - val_loss: 0.0426 - val_categorical_accuracy: 0.9889
# Epoch 18/20
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0047 - categorical_accuracy: 0.9986 - val_loss: 0.0546 - val_categorical_accuracy: 0.9886
# Epoch 19/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0061 - categorical_accuracy: 0.9981 - val_loss: 0.0472 - val_categorical_accuracy: 0.9888
# Epoch 20/20
# 60000/60000 [==============================] - 4s 65us/step - loss: 0.0050 - categorical_accuracy: 0.9985 - val_loss: 0.0558 - val_categorical_accuracy: 0.9889

# %% [markdown]
# Beyond 10 epochs the model began to overfit so training was stopped there. The model was able to achieve an accuracy of about 91.5%.

# %% [markdown]
# Next, the hybrid model is trained and compared to the regular CNN.

# %%
def train_hybrid():
    model = keras.Sequential([
        layers.Reshape((28,28,1), input_shape=(28,28)),
        layers.Conv2D(16, (3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(32, (3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(64, (3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Flatten(),
        GaussMembership(10),
        layers.Lambda(lambda x: normalized_product_fn(x)),
        layers.Dense(10, activation="sigmoid"),
    ])
    
    model.compile(
        optimizer="adam",
        loss="binary_crossentropy",
        metrics=[keras.metrics.categorical_accuracy])

    # train the model
    history = model.fit(
        x=train_x,
        y=train_y,
        batch_size=64,
        epochs=20,
        validation_data=(test_x, test_y),
        verbose=1,
        shuffle=True)
    
    # plot the loss and accuracy
    fig, axes = plt.subplots(1, 2, figsize=(8, 4), squeeze=True)
    axes[0].set_title("Loss")
    axes[0].plot(history.history["loss"], c="b")
    axes[0].plot(history.history["val_loss"], c="r")

    axes[1].set_title("Accuracy")
    axes[1].plot(history.history["categorical_accuracy"], c="b")
    axes[1].plot(history.history["val_categorical_accuracy"], c="r")


train_hybrid()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 84us/step - loss: 0.2608 - categorical_accuracy: 0.6593 - val_loss: 0.1706 - val_categorical_accuracy: 0.9489
# Epoch 2/20
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.1302 - categorical_accuracy: 0.9552 - val_loss: 0.0968 - val_categorical_accuracy: 0.9685
# Epoch 3/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0767 - categorical_accuracy: 0.9702 - val_loss: 0.0599 - val_categorical_accuracy: 0.9732
# Epoch 4/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0487 - categorical_accuracy: 0.9769 - val_loss: 0.0407 - val_categorical_accuracy: 0.9780
# Epoch 5/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0333 - categorical_accuracy: 0.9816 - val_loss: 0.0294 - val_categorical_accuracy: 0.9801
# Epoch 6/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0240 - categorical_accuracy: 0.9856 - val_loss: 0.0238 - val_categorical_accuracy: 0.9812
# Epoch 7/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0181 - categorical_accuracy: 0.9876 - val_loss: 0.0196 - val_categorical_accuracy: 0.9834
# Epoch 8/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0143 - categorical_accuracy: 0.9895 - val_loss: 0.0177 - val_categorical_accuracy: 0.9825
# Epoch 9/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0114 - categorical_accuracy: 0.9912 - val_loss: 0.0146 - val_categorical_accuracy: 0.9841
# Epoch 10/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0092 - categorical_accuracy: 0.9930 - val_loss: 0.0140 - val_categorical_accuracy: 0.9851
# Epoch 11/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0079 - categorical_accuracy: 0.9935 - val_loss: 0.0126 - val_categorical_accuracy: 0.9857
# Epoch 12/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0066 - categorical_accuracy: 0.9949 - val_loss: 0.0133 - val_categorical_accuracy: 0.9850
# Epoch 13/20
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0056 - categorical_accuracy: 0.9955 - val_loss: 0.0128 - val_categorical_accuracy: 0.9832
# Epoch 14/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0049 - categorical_accuracy: 0.9961 - val_loss: 0.0120 - val_categorical_accuracy: 0.9855
# Epoch 15/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0044 - categorical_accuracy: 0.9966 - val_loss: 0.0122 - val_categorical_accuracy: 0.9859
# Epoch 16/20
# 60000/60000 [==============================] - 5s 75us/step - loss: 0.0037 - categorical_accuracy: 0.9974 - val_loss: 0.0120 - val_categorical_accuracy: 0.9848
# Epoch 17/20
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0033 - categorical_accuracy: 0.9977 - val_loss: 0.0132 - val_categorical_accuracy: 0.9834
# Epoch 18/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0031 - categorical_accuracy: 0.9979 - val_loss: 0.0124 - val_categorical_accuracy: 0.9840
# Epoch 19/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0026 - categorical_accuracy: 0.9984 - val_loss: 0.0130 - val_categorical_accuracy: 0.9843
# Epoch 20/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0027 - categorical_accuracy: 0.9980 - val_loss: 0.0120 - val_categorical_accuracy: 0.9848

# %% [markdown]
# The model took longer to train than the regular CNN, likely due to the small gradients in the membership layer. In 20 epochs it was able to achieve approx 91.0% on the out of sample validation data.
