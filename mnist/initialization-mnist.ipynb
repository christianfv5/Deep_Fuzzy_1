# %%
import gzip
import numpy as np
import matplotlib.pyplot as plt

def load_data(filename, dims):
    with gzip.open(filename, "rb") as infile:
        # consume magic number
        infile.read(4)
        # consume dimensions data
        infile.read(4 * len(dims))

        return np.frombuffer(infile.read(np.prod(dims)), dtype=np.uint8).reshape(dims)

# training data
train_images = load_data("data/train-images-idx3-ubyte.gz", [60000, 784])
train_labels = load_data("data/train-labels-idx1-ubyte.gz", [60000])

# testing data
test_images = load_data("data/t10k-images-idx3-ubyte.gz", [10000, 784])
test_labels = load_data("data/t10k-labels-idx1-ubyte.gz", [10000])

# %%
train_x = train_images.astype(np.float) / 255
train_y = np.zeros((60000, 10))
train_y[np.arange(60000),train_labels] = 1

test_x = test_images.astype(np.float) / 255
test_y = np.zeros((10000, 10))
test_y[np.arange(10000),test_labels] = 1

# %%
import keras
import keras.layers as layers
import keras.models as models
from model import GaussMembership, normalized_product_fn


def create_model(init_mu, init_sigma, num_rules=10):
    model = keras.Sequential([
        GaussMembership(num_rules, input_shape=(784,)),
        layers.Lambda(lambda x: normalized_product_fn(x)),
        layers.Dense(10, activation="sigmoid"),])
    model.layers[0].set_weights([init_mu, init_sigma])
    return model
# Out:
# Using TensorFlow backend.

# %%
import os
import pickle
from umap import UMAP
from sklearn.decomposition import PCA


def create_embeddings(data, ignore_cache=False):
    umap_dir = "cache/umap.pickle"
    pca_dir = "cache/pca.pickle"

    if not os.path.isfile(umap_dir) or ignore_cache:
        umap_reducer = UMAP(random_state=42).fit(data)
        pickle.dump(umap_reducer, open(umap_dir, "wb"))
    else:
        umap_reducer = pickle.load(open(umap_dir, "rb"))

    if not os.path.isfile(pca_dir) or ignore_cache:
        pca_reducer = PCA(n_components=2, random_state=42).fit(data)
        pickle.dump(pca_reducer, open(pca_dir, "wb"))
    else:
        pca_reducer = pickle.load(open(pca_dir, "rb"))
        
    return umap_reducer, pca_reducer


umap_reducer, pca_reducer = create_embeddings(train_x, ignore_cache=False)
umap_data = umap_reducer.transform(train_x)
pca_data = pca_reducer.transform(train_x)

fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
axes[0].scatter(umap_data[:,0], umap_data[:,1], s=1, c=train_labels, cmap='Spectral')
axes[0].set_title("UMAP Embedding")

axes[1].scatter(pca_data[:,0], pca_data[:,1], s=1, c=train_labels, cmap='Spectral')
axes[1].set_title("PCA Embedding")
plt.setp(axes, xticks=[], yticks=[])
plt.tight_layout()

# %%
def random_parameters(data, num_rules):
    data_min = np.min(data, axis=0)
    data_max = np.max(data, axis=0)
    init_mu = (data_max - data_min) * np.random.rand(num_rules, data.shape[1]) + data_min
    init_sigma = np.ones((num_rules, 1)) + (data_max - data_min)
    return init_mu, init_sigma


init_mu, init_sigma = random_parameters(train_x, 10)
model = create_model(init_mu, init_sigma)

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=[keras.metrics.categorical_accuracy])

random_history = model.fit(
    x=train_x,
    y=train_y,
    batch_size=64,
    epochs=50,
    verbose=1,
    shuffle=True)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0211 15:58:14.265258 139982919419712 deprecation.py:323] From /home/ryan-desktop/anaconda3/envs/keras/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.3317 - categorical_accuracy: 0.3693
# Epoch 2/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.2319 - categorical_accuracy: 0.7498
# Epoch 3/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1817 - categorical_accuracy: 0.8098
# Epoch 4/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.1476 - categorical_accuracy: 0.8412
# Epoch 5/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1248 - categorical_accuracy: 0.8617
# Epoch 6/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1088 - categorical_accuracy: 0.8767
# Epoch 7/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0967 - categorical_accuracy: 0.8907
# Epoch 8/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0871 - categorical_accuracy: 0.8992
# Epoch 9/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0798 - categorical_accuracy: 0.9052
# Epoch 10/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0740 - categorical_accuracy: 0.9101
# Epoch 11/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0695 - categorical_accuracy: 0.9139
# Epoch 12/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0660 - categorical_accuracy: 0.9157
# Epoch 13/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0629 - categorical_accuracy: 0.9198
# Epoch 14/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0606 - categorical_accuracy: 0.9223
# Epoch 15/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0584 - categorical_accuracy: 0.9246
# Epoch 16/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0564 - categorical_accuracy: 0.9268
# Epoch 17/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0550 - categorical_accuracy: 0.9283
# Epoch 18/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0535 - categorical_accuracy: 0.9299
# Epoch 19/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0523 - categorical_accuracy: 0.9316
# Epoch 20/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0510 - categorical_accuracy: 0.9329
# Epoch 21/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0500 - categorical_accuracy: 0.9342
# Epoch 22/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0491 - categorical_accuracy: 0.9344
# Epoch 23/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0480 - categorical_accuracy: 0.9359
# Epoch 24/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0474 - categorical_accuracy: 0.9370
# Epoch 25/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0466 - categorical_accuracy: 0.9380
# Epoch 26/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0459 - categorical_accuracy: 0.9387
# Epoch 27/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0453 - categorical_accuracy: 0.9393
# Epoch 28/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0447 - categorical_accuracy: 0.9401
# Epoch 29/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0442 - categorical_accuracy: 0.9404
# Epoch 30/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0436 - categorical_accuracy: 0.9413
# Epoch 31/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0432 - categorical_accuracy: 0.9421
# Epoch 32/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0427 - categorical_accuracy: 0.9425
# Epoch 33/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0423 - categorical_accuracy: 0.9424
# Epoch 34/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0418 - categorical_accuracy: 0.9435
# Epoch 35/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0415 - categorical_accuracy: 0.9445
# Epoch 36/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0410 - categorical_accuracy: 0.9448
# Epoch 37/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0409 - categorical_accuracy: 0.9446
# Epoch 38/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0403 - categorical_accuracy: 0.9453
# Epoch 39/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0399 - categorical_accuracy: 0.9459
# Epoch 40/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0399 - categorical_accuracy: 0.9464
# Epoch 41/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0394 - categorical_accuracy: 0.9470
# Epoch 42/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0391 - categorical_accuracy: 0.9470
# Epoch 43/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0390 - categorical_accuracy: 0.9470
# Epoch 44/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0383 - categorical_accuracy: 0.9487
# Epoch 45/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0384 - categorical_accuracy: 0.9482
# Epoch 46/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0381 - categorical_accuracy: 0.9480
# Epoch 47/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0379 - categorical_accuracy: 0.9489
# Epoch 48/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0378 - categorical_accuracy: 0.9488
# Epoch 49/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0374 - categorical_accuracy: 0.9495
# Epoch 50/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0373 - categorical_accuracy: 0.9491

# %%
def plot_cluster_movement(ax, data, init, current):
    change = current - init
    
    ax.scatter(data[:,0], data[:,1], s=1, c=train_labels, cmap='Spectral')
    s1 = ax.scatter(init[:,0], init[:,1], s=100, c="k", marker="^")
    s2 = ax.scatter(current[:,0], current[:,1], s=100, c="r", marker="^")
    
    for i in range(change.shape[0]):
        ax.arrow(init[i,0], init[i,1], change[i,0], change[i,1])
    ax.legend([s1, s2], ["Before Training", "After Training"])


current_mu = model.layers[0].get_weights()[0]

fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
axes[0].set_title("Cluster Movement (UMAP)")
plot_cluster_movement(
    axes[0], umap_data,
    umap_reducer.transform(init_mu), 
    umap_reducer.transform(current_mu))

axes[1].set_title("Cluster Movement (PCA)")
plot_cluster_movement(
    axes[1], pca_data,
    pca_reducer.transform(init_mu), 
    pca_reducer.transform(current_mu))

plt.setp(axes, xticks=[], yticks=[])
plt.tight_layout()

# %%
import skfuzzy as skf


def fcm_parameters(data, c, m, ignore_cache=False):
    cache_dir = "cache/mu_fcm.pickle"
    
    if not os.path.isfile(cache_dir) or ignore_cache:
        centers, memberships, u0, d, jm, p, fpc = skf.cmeans(
            data.T, c, m, 1e-8, 1000, seed=0)
        pickle.dump(centers, open(cache_dir, "wb"))
    else:
        centers = pickle.load(open(cache_dir, "rb"))
        
    sigmas = np.ones((c, data.shape[1]))
    return centers, sigmas


init_mu, init_sigma = fcm_parameters(train_x, 10, 1.1)
model = create_model(init_mu, init_sigma)

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=[keras.metrics.categorical_accuracy])

fcm_history = model.fit(
    x=train_x,
    y=train_y,
    batch_size=64,
    epochs=50,
    verbose=1,
    shuffle=True)
# Out:
# Epoch 1/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.4134 - categorical_accuracy: 0.1957
# Epoch 2/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.2860 - categorical_accuracy: 0.3739
# Epoch 3/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.2554 - categorical_accuracy: 0.4510
# Epoch 4/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.2068 - categorical_accuracy: 0.6725
# Epoch 5/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1406 - categorical_accuracy: 0.8269
# Epoch 6/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1158 - categorical_accuracy: 0.8710
# Epoch 7/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1003 - categorical_accuracy: 0.8943
# Epoch 8/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0893 - categorical_accuracy: 0.9030
# Epoch 9/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0815 - categorical_accuracy: 0.9073
# Epoch 10/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0759 - categorical_accuracy: 0.9110
# Epoch 11/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0715 - categorical_accuracy: 0.9147
# Epoch 12/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0682 - categorical_accuracy: 0.9161
# Epoch 13/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0657 - categorical_accuracy: 0.9177
# Epoch 14/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0634 - categorical_accuracy: 0.9189
# Epoch 15/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0615 - categorical_accuracy: 0.9215
# Epoch 16/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0600 - categorical_accuracy: 0.9223
# Epoch 17/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0583 - categorical_accuracy: 0.9235
# Epoch 18/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0570 - categorical_accuracy: 0.9254
# Epoch 19/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0559 - categorical_accuracy: 0.9253
# Epoch 20/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0549 - categorical_accuracy: 0.9269
# Epoch 21/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0539 - categorical_accuracy: 0.9283
# Epoch 22/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0532 - categorical_accuracy: 0.9287
# Epoch 23/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0525 - categorical_accuracy: 0.9291
# Epoch 24/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0518 - categorical_accuracy: 0.9299
# Epoch 25/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0512 - categorical_accuracy: 0.9298
# Epoch 26/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0506 - categorical_accuracy: 0.9308
# Epoch 27/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0499 - categorical_accuracy: 0.9319
# Epoch 28/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0497 - categorical_accuracy: 0.9323
# Epoch 29/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0492 - categorical_accuracy: 0.9326
# Epoch 30/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0488 - categorical_accuracy: 0.9330
# Epoch 31/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0483 - categorical_accuracy: 0.9340
# Epoch 32/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0481 - categorical_accuracy: 0.9343
# Epoch 33/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0478 - categorical_accuracy: 0.9331
# Epoch 34/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0475 - categorical_accuracy: 0.9347
# Epoch 35/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0472 - categorical_accuracy: 0.9354
# Epoch 36/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0470 - categorical_accuracy: 0.9352
# Epoch 37/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0469 - categorical_accuracy: 0.9356
# Epoch 38/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0465 - categorical_accuracy: 0.9363
# Epoch 39/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0463 - categorical_accuracy: 0.9370
# Epoch 40/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0463 - categorical_accuracy: 0.9361
# Epoch 41/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0461 - categorical_accuracy: 0.9371
# Epoch 42/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0460 - categorical_accuracy: 0.9366
# Epoch 43/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0455 - categorical_accuracy: 0.9369
# Epoch 44/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0451 - categorical_accuracy: 0.9382
# Epoch 45/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0451 - categorical_accuracy: 0.9377
# Epoch 46/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0449 - categorical_accuracy: 0.9380
# Epoch 47/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0449 - categorical_accuracy: 0.9381
# Epoch 48/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0446 - categorical_accuracy: 0.9388
# Epoch 49/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0447 - categorical_accuracy: 0.9390
# Epoch 50/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0447 - categorical_accuracy: 0.9395

# %%
current_mu = model.layers[0].get_weights()[0]

fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
axes[0].set_title("Cluster Movement (UMAP)")
plot_cluster_movement(
    axes[0], umap_data,
    umap_reducer.transform(init_mu), 
    umap_reducer.transform(current_mu))

axes[1].set_title("Cluster Movement (PCA)")
plot_cluster_movement(
    axes[1], pca_data,
    pca_reducer.transform(init_mu), 
    pca_reducer.transform(current_mu))

plt.setp(axes, xticks=[], yticks=[])
plt.tight_layout()

# %%
import GK as gk


def gk_parameters(data, c, m, ignore_cache=False):
    cache_dir = "cache/mu_gk.pickle"
    
    if not os.path.isfile(cache_dir) or ignore_cache:
        centers, memberships, u0, d, jm, p, fpc = gk.cmeans(
            data.T, c, m, 1e-8, 1000, seed=0)
        pickle.dump(centers, open(cache_dir, "wb"))
    else:
        centers = pickle.load(open(cache_dir, "rb"))
        
    sigmas = np.ones((c, data.shape[1]))
    return centers, sigmas


init_mu, init_sigma = gk_parameters(train_x, 10, 2.0, ignore_cache=True)
model = create_model(init_mu, init_sigma)

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=[keras.metrics.categorical_accuracy])

gk_history = model.fit(
    x=train_x,
    y=train_y,
    batch_size=64,
    epochs=50,
    verbose=1,
    shuffle=True)
# Out:
# Error Threshold 2
# Epoch 1/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.3355 - categorical_accuracy: 0.3814
# Epoch 2/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.2213 - categorical_accuracy: 0.7815
# Epoch 3/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1685 - categorical_accuracy: 0.8379
# Epoch 4/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1354 - categorical_accuracy: 0.8630
# Epoch 5/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1127 - categorical_accuracy: 0.8811
# Epoch 6/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0966 - categorical_accuracy: 0.8947
# Epoch 7/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0850 - categorical_accuracy: 0.9052
# Epoch 8/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0768 - categorical_accuracy: 0.9110
# Epoch 9/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0708 - categorical_accuracy: 0.9165
# Epoch 10/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0665 - categorical_accuracy: 0.9204
# Epoch 11/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0631 - categorical_accuracy: 0.9235
# Epoch 12/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0603 - categorical_accuracy: 0.9252
# Epoch 13/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0581 - categorical_accuracy: 0.9276
# Epoch 14/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0562 - categorical_accuracy: 0.9296
# Epoch 15/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0544 - categorical_accuracy: 0.9305
# Epoch 16/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0528 - categorical_accuracy: 0.9324
# Epoch 17/50
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0517 - categorical_accuracy: 0.9332
# Epoch 18/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0505 - categorical_accuracy: 0.9348
# Epoch 19/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0494 - categorical_accuracy: 0.9352
# Epoch 20/50
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.0484 - categorical_accuracy: 0.9369
# Epoch 21/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0473 - categorical_accuracy: 0.9374
# Epoch 22/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0467 - categorical_accuracy: 0.9378
# Epoch 23/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0456 - categorical_accuracy: 0.9403
# Epoch 24/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0453 - categorical_accuracy: 0.9395
# Epoch 25/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0445 - categorical_accuracy: 0.9407
# Epoch 26/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0439 - categorical_accuracy: 0.9416
# Epoch 27/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0432 - categorical_accuracy: 0.9423
# Epoch 28/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0429 - categorical_accuracy: 0.9419
# Epoch 29/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0424 - categorical_accuracy: 0.9428
# Epoch 30/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0417 - categorical_accuracy: 0.9442
# Epoch 31/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0412 - categorical_accuracy: 0.9441
# Epoch 32/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0410 - categorical_accuracy: 0.9443
# Epoch 33/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0406 - categorical_accuracy: 0.9450
# Epoch 34/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0403 - categorical_accuracy: 0.9453
# Epoch 35/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0397 - categorical_accuracy: 0.9460
# Epoch 36/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0393 - categorical_accuracy: 0.9466
# Epoch 37/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0391 - categorical_accuracy: 0.9472
# Epoch 38/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0385 - categorical_accuracy: 0.9475
# Epoch 39/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0385 - categorical_accuracy: 0.9467
# Epoch 40/50
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.0381 - categorical_accuracy: 0.9476
# Epoch 41/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0378 - categorical_accuracy: 0.9480
# Epoch 42/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0375 - categorical_accuracy: 0.9488
# Epoch 43/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0371 - categorical_accuracy: 0.9480
# Epoch 44/50
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0371 - categorical_accuracy: 0.9495
# Epoch 45/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0367 - categorical_accuracy: 0.9491
# Epoch 46/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0368 - categorical_accuracy: 0.9488
# Epoch 47/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0365 - categorical_accuracy: 0.9502
# Epoch 48/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0360 - categorical_accuracy: 0.9502
# Epoch 49/50
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0359 - categorical_accuracy: 0.9507
# Epoch 50/50
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0359 - categorical_accuracy: 0.9506

# %%
current_mu = model.layers[0].get_weights()[0]

fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
axes[0].set_title("Cluster Movement (UMAP)")
plot_cluster_movement(
    axes[0], umap_data,
    umap_reducer.transform(init_mu), 
    umap_reducer.transform(current_mu))

axes[1].set_title("Cluster Movement (PCA)")
plot_cluster_movement(
    axes[1], pca_data,
    pca_reducer.transform(init_mu), 
    pca_reducer.transform(current_mu))

plt.setp(axes, xticks=[], yticks=[])
plt.tight_layout()

# %%
fig, axes = plt.subplots(1, 2, squeeze=True, figsize=(8,4))
axes[0].set_title("Training Log-Loss Comparison")
axes[0].plot(np.log(random_history.history["loss"]), c="r")
axes[0].plot(np.log(fcm_history.history["loss"]), c="g")
axes[0].plot(np.log(gk_history.history["loss"]), c="b")
axes[0].legend(["Random", "FCM", "GK"])

axes[1].set_title("Training Accuracy Comparison")
axes[1].set_ylim((0.9, 1))
axes[1].plot(random_history.history["categorical_accuracy"], c="r")
axes[1].plot(fcm_history.history["categorical_accuracy"], c="g")
axes[1].plot(gk_history.history["categorical_accuracy"], c="b")
axes[1].legend(["Random", "FCM", "GK"])

plt.tight_layout()
