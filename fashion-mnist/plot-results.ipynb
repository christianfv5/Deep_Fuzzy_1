# %%
import re
import matplotlib.pyplot as plt


def read_history(filename):
    history = {
        "loss": [],
        "acc": [],
        "val_loss": [],
        "val_acc": [],
    }

    with open(filename, "r") as infile:
        for line in infile:
            line = line.strip()
            idx = line.find("- loss:")

            if idx == -1:
                continue

            data = re.split(" ?\- [a-z_]+: ", line[idx:])[1:]
            loss, acc, val_loss, val_acc = map(lambda x: float(x), data)

            history["loss"].append(loss)
            history["acc"].append(acc)
            history["val_loss"].append(val_loss)
            history["val_acc"].append(val_acc)
            
    return history

# %%
lenet_history = read_history("training_history/lenet.txt")
anfis_lenet_history = read_history("training_history/anfis_lenet.txt")


plt.figure(figsize=(8,6))

ax1, = plt.plot(lenet_history["acc"], "g--")
ax2, = plt.plot(lenet_history["val_acc"], "g")
ax3, = plt.plot(anfis_lenet_history["acc"], "r--")
ax4, = plt.plot(anfis_lenet_history["val_acc"], "r")

plt.title("Fashion MNIST Accuracy")

plt.xlabel("Epoch")

plt.ylabel("Accuracy")
plt.ylim(0.85, 0.95)

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["LeNet Training Set", 
     "LeNet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/lenet_fmnist_acc.pdf")


plt.figure(figsize=(8,6))

ax1, = plt.plot(lenet_history["loss"], "g--")
ax2, = plt.plot(lenet_history["val_loss"], "g")
ax3, = plt.plot(anfis_lenet_history["loss"], "r--")
ax4, = plt.plot(anfis_lenet_history["val_loss"], "r")

plt.title("Fashion MNIST Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["LeNet Training Set", 
     "LeNet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/lenet_fmnist_loss.pdf")

# %%
plt.figure(figsize=(8,6))

ax1, = plt.plot(lenet_history["acc"][:30], "g--")
ax2, = plt.plot(lenet_history["val_acc"][:30], "g")
ax3, = plt.plot(anfis_lenet_history["acc"][:30], "r--")
ax4, = plt.plot(anfis_lenet_history["val_acc"][:30], "r")

plt.title("Fashion MNIST Accuracy")

plt.xlabel("Epoch")

plt.ylabel("Accuracy")
plt.ylim(0.85, 0.90)

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["LeNet Training Set", 
     "LeNet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/lenet_fmnist_acc_30.pdf")


plt.figure(figsize=(8,6))

ax1, = plt.plot(lenet_history["loss"][:30], "g--")
ax2, = plt.plot(lenet_history["val_loss"][:30], "g")
ax3, = plt.plot(anfis_lenet_history["loss"][:30], "r--")
ax4, = plt.plot(anfis_lenet_history["val_loss"][:30], "r")

plt.title("Fashion MNIST Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["LeNet Training Set", 
     "LeNet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/lenet_fmnist_loss_30.pdf")

# %%
resnet_history = read_history("training_history/resnet29.txt")
anfis_resnet_history = read_history("training_history/dnfis_resnet29.txt")


plt.figure(figsize=(8,6))

ax1, = plt.plot(resnet_history["acc"], "g--")
ax2, = plt.plot(resnet_history["val_acc"], "g")
ax3, = plt.plot(anfis_resnet_history["acc"], "r--")
ax4, = plt.plot(anfis_resnet_history["val_acc"], "r")

plt.title("Fashion MNIST Accuracy")

plt.xlabel("Epoch")

plt.ylabel("Accuracy")
plt.ylim(0.90, 1.0)

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["Resnet Training Set", 
     "Resnet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/resnet_fmnist_acc.pdf")


plt.figure(figsize=(8,6))

ax1, = plt.plot(resnet_history["loss"], "g--")
ax2, = plt.plot(resnet_history["val_loss"], "g")
ax3, = plt.plot(anfis_resnet_history["loss"], "r--")
ax4, = plt.plot(anfis_resnet_history["val_loss"], "r")

plt.title("Fashion MNIST Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["Resnet Training Set", 
     "Resnet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/resnet_fmnist_loss.pdf")

# %%
plt.figure(figsize=(8,6))

ax1, = plt.plot(resnet_history["acc"][:30], "g--")
ax2, = plt.plot(resnet_history["val_acc"][:30], "g")
ax3, = plt.plot(anfis_resnet_history["acc"][:30], "r--")
ax4, = plt.plot(anfis_resnet_history["val_acc"][:30], "r")

plt.title("Fashion MNIST Accuracy")

plt.xlabel("Epoch")

plt.ylabel("Accuracy")
plt.ylim(0.80, 0.95)

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["Resnet Training Set", 
     "Resnet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/resnet_fmnist_acc_30.pdf")


plt.figure(figsize=(8,6))

ax1, = plt.plot(resnet_history["loss"][:30], "g--")
ax2, = plt.plot(resnet_history["val_loss"][:30], "g")
ax3, = plt.plot(anfis_resnet_history["loss"][:30], "r--")
ax4, = plt.plot(anfis_resnet_history["val_loss"][:30], "r")

plt.title("Fashion MNIST Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["Resnet Training Set", 
     "Resnet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

plt.savefig("figures/resnet_fmnist_loss_30.pdf")
