# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt

import keras
from keras.datasets import fashion_mnist

# Load the MNIST data.
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# If subtract pixel mean is enabled
x_train_mean = np.mean(x_train, axis=0)
x_train -= x_train_mean
x_test -= x_train_mean

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Input image dimensions.
input_shape = x_train.shape[1:]
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import *
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from model import LogGaussMF


def lenet_backend(input_shape):
    inputs = Input(shape=input_shape)
    c1 = Conv2D(filters=6, kernel_size=5, activation="relu")(inputs)
    s2 = AveragePooling2D(pool_size=2)(c1)
    c3 = Conv2D(filters=16, kernel_size=5, activation="relu")(s2)
    s4 = AveragePooling2D(pool_size=2)(c3)
    c5 = Dense(120, activation="relu")(Flatten()(s4))
    return inputs, c5


model_type = "LeNet"

save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = "%s_model.{epoch:03d}.h5" % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

checkpoint = ModelCheckpoint(
    filepath=filepath,
    monitor='val_acc',
    verbose=1,
    save_best_only=True)

inputs, c5 = lenet_backend(input_shape=input_shape)
f6 = Dense(84, activation="relu")(c5)
f7 = Dense(10, activation="softmax")(f6)
model = Model(inputs=inputs, outputs=f7)

model.compile(
    optimizer="adam",
    loss='categorical_crossentropy',
    metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 6)         156
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               30840
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                850
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator


datagen = ImageDataGenerator(
    # set input mean to 0 over the dataset
    featurewise_center=False,
    # set each sample mean to 0
    samplewise_center=False,
    # divide inputs by std of dataset
    featurewise_std_normalization=False,
    # divide each input by its std
    samplewise_std_normalization=False,
    # apply ZCA whitening
    zca_whitening=False,
    # epsilon for ZCA whitening
    zca_epsilon=1e-06,
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=0,
    # randomly shift images horizontally
    width_shift_range=0.1,
    # randomly shift images vertically
    height_shift_range=0.1,
    # set range for random shear
    shear_range=0.,
    # set range for random zoom
    zoom_range=0.,
    # set range for random channel shifts
    channel_shift_range=0.,
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    # value used for fill_mode = "constant"
    cval=0.,
    # randomly flip images
    horizontal_flip=True,
    # randomly flip images
    vertical_flip=False,
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)


datagen.fit(x_train)
batch_size = 32

history = model.fit_generator(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=60000 // batch_size,
    validation_data=(x_test, y_test),
    epochs=20, 
    verbose=1, 
    workers=4,
    callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.8098 - acc: 0.6922 - val_loss: 0.6070 - val_acc: 0.7725
#
# Epoch 00001: val_acc improved from -inf to 0.77250, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.001.h5
# Epoch 2/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.5884 - acc: 0.7774 - val_loss: 0.5494 - val_acc: 0.7878
#
# Epoch 00002: val_acc improved from 0.77250 to 0.78780, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.002.h5
# Epoch 3/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.5163 - acc: 0.8068 - val_loss: 0.4395 - val_acc: 0.8383
#
# Epoch 00003: val_acc improved from 0.78780 to 0.83830, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.003.h5
# Epoch 4/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4708 - acc: 0.8237 - val_loss: 0.4155 - val_acc: 0.8444
#
# Epoch 00004: val_acc improved from 0.83830 to 0.84440, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.004.h5
# Epoch 5/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4439 - acc: 0.8340 - val_loss: 0.3985 - val_acc: 0.8515
#
# Epoch 00005: val_acc improved from 0.84440 to 0.85150, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.005.h5
# Epoch 6/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4192 - acc: 0.8437 - val_loss: 0.3922 - val_acc: 0.8523
#
# Epoch 00006: val_acc improved from 0.85150 to 0.85230, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.006.h5
# Epoch 7/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4045 - acc: 0.8498 - val_loss: 0.4003 - val_acc: 0.8507
#
# Epoch 00007: val_acc did not improve from 0.85230
# Epoch 8/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3930 - acc: 0.8548 - val_loss: 0.3728 - val_acc: 0.8596
#
# Epoch 00008: val_acc improved from 0.85230 to 0.85960, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.008.h5
# Epoch 9/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3829 - acc: 0.8576 - val_loss: 0.3743 - val_acc: 0.8623
#
# Epoch 00009: val_acc improved from 0.85960 to 0.86230, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.009.h5
# Epoch 10/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3731 - acc: 0.8595 - val_loss: 0.3512 - val_acc: 0.8723
#
# Epoch 00010: val_acc improved from 0.86230 to 0.87230, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.010.h5
# Epoch 11/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3645 - acc: 0.8634 - val_loss: 0.3490 - val_acc: 0.8754
#
# Epoch 00011: val_acc improved from 0.87230 to 0.87540, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.011.h5
# Epoch 12/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3610 - acc: 0.8648 - val_loss: 0.3481 - val_acc: 0.8722
#
# Epoch 00012: val_acc did not improve from 0.87540
# Epoch 13/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3523 - acc: 0.8674 - val_loss: 0.3450 - val_acc: 0.8707
#
# Epoch 00013: val_acc did not improve from 0.87540
# Epoch 14/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3457 - acc: 0.8706 - val_loss: 0.3580 - val_acc: 0.8663
#
# Epoch 00014: val_acc did not improve from 0.87540
# Epoch 15/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3424 - acc: 0.8725 - val_loss: 0.3262 - val_acc: 0.8821
#
# Epoch 00015: val_acc improved from 0.87540 to 0.88210, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.015.h5
# Epoch 16/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3393 - acc: 0.8734 - val_loss: 0.3342 - val_acc: 0.8788
#
# Epoch 00016: val_acc did not improve from 0.88210
# Epoch 17/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3338 - acc: 0.8747 - val_loss: 0.3394 - val_acc: 0.8765
#
# Epoch 00017: val_acc did not improve from 0.88210
# Epoch 18/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.3334 - acc: 0.8759 - val_loss: 0.3350 - val_acc: 0.8758
#
# Epoch 00018: val_acc did not improve from 0.88210
# Epoch 19/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3261 - acc: 0.8783 - val_loss: 0.3216 - val_acc: 0.8842
#
# Epoch 00019: val_acc improved from 0.88210 to 0.88420, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/LeNet_model.019.h5
# Epoch 20/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3233 - acc: 0.8791 - val_loss: 0.3237 - val_acc: 0.8826
#
# Epoch 00020: val_acc did not improve from 0.88420

# %%
model_type = "Fuzzy-LeNet"

save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = "%s_model.{epoch:03d}.h5" % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

checkpoint = ModelCheckpoint(
    filepath=filepath,
    monitor='val_acc',
    verbose=1,
    save_best_only=True)


inputs, c5 = lenet_backend(input_shape=input_shape)
memberships = LogGaussMF(10)(c5)
rules = Lambda(lambda x: K.sum(x, axis=-1))(memberships)
linear = Dense(10)(c5)
logits = Add()([rules, linear])
outputs = Activation("softmax")(logits)
model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer="adam",
    loss='categorical_crossentropy',
    metrics=['accuracy'])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 6)    156         input_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 12, 12, 6)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 16)     2416        average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 4, 4, 16)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 256)          0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 120)          30840       flatten_2[0][0]
# __________________________________________________________________________________________________
# log_gauss_mf_1 (LogGaussMF)     (None, 10, 120)      2400        dense_4[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 10)           0           log_gauss_mf_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           1210        dense_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10)           0           lambda_1[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10)           0           add_1[0][0]
# ==================================================================================================
# Total params: 37,022
# Trainable params: 37,022
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
datagen = ImageDataGenerator(
    # set input mean to 0 over the dataset
    featurewise_center=False,
    # set each sample mean to 0
    samplewise_center=False,
    # divide inputs by std of dataset
    featurewise_std_normalization=False,
    # divide each input by its std
    samplewise_std_normalization=False,
    # apply ZCA whitening
    zca_whitening=False,
    # epsilon for ZCA whitening
    zca_epsilon=1e-06,
    # randomly rotate images in the range (deg 0 to 180)
    rotation_range=0,
    # randomly shift images horizontally
    width_shift_range=0.1,
    # randomly shift images vertically
    height_shift_range=0.1,
    # set range for random shear
    shear_range=0.,
    # set range for random zoom
    zoom_range=0.,
    # set range for random channel shifts
    channel_shift_range=0.,
    # set mode for filling points outside the input boundaries
    fill_mode='nearest',
    # value used for fill_mode = "constant"
    cval=0.,
    # randomly flip images
    horizontal_flip=True,
    # randomly flip images
    vertical_flip=False,
    # set rescaling factor (applied before any other transformation)
    rescale=None,
    # set function that will be applied on each input
    preprocessing_function=None,
    # image data format, either "channels_first" or "channels_last"
    data_format=None,
    # fraction of images reserved for validation (strictly between 0 and 1)
    validation_split=0.0)


datagen.fit(x_train)
batch_size = 32

fuzzy_history = model.fit_generator(
    datagen.flow(x_train, y_train, batch_size=batch_size),
    steps_per_epoch=60000 // batch_size,
    validation_data=(x_test, y_test),
    epochs=20, 
    verbose=1, 
    workers=4,
    callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.7959 - acc: 0.7039 - val_loss: 0.6158 - val_acc: 0.7674
#
# Epoch 00001: val_acc improved from -inf to 0.76740, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.001.h5
# Epoch 2/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5870 - acc: 0.7779 - val_loss: 0.4966 - val_acc: 0.8136
#
# Epoch 00002: val_acc improved from 0.76740 to 0.81360, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.002.h5
# Epoch 3/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5257 - acc: 0.8036 - val_loss: 0.4484 - val_acc: 0.8345
#
# Epoch 00003: val_acc improved from 0.81360 to 0.83450, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.003.h5
# Epoch 4/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4760 - acc: 0.8222 - val_loss: 0.4193 - val_acc: 0.8514
#
# Epoch 00004: val_acc improved from 0.83450 to 0.85140, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.004.h5
# Epoch 5/20
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4516 - acc: 0.8326 - val_loss: 0.4032 - val_acc: 0.8533
#
# Epoch 00005: val_acc improved from 0.85140 to 0.85330, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.005.h5
# Epoch 6/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.4323 - acc: 0.8395 - val_loss: 0.3950 - val_acc: 0.8526
#
# Epoch 00006: val_acc did not improve from 0.85330
# Epoch 7/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4165 - acc: 0.8468 - val_loss: 0.3772 - val_acc: 0.8625
#
# Epoch 00007: val_acc improved from 0.85330 to 0.86250, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.007.h5
# Epoch 8/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4028 - acc: 0.8510 - val_loss: 0.3870 - val_acc: 0.8572
#
# Epoch 00008: val_acc did not improve from 0.86250
# Epoch 9/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3902 - acc: 0.8556 - val_loss: 0.3615 - val_acc: 0.8663
#
# Epoch 00009: val_acc improved from 0.86250 to 0.86630, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.009.h5
# Epoch 10/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3819 - acc: 0.8586 - val_loss: 0.3568 - val_acc: 0.8731
#
# Epoch 00010: val_acc improved from 0.86630 to 0.87310, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.010.h5
# Epoch 11/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3755 - acc: 0.8623 - val_loss: 0.3443 - val_acc: 0.8762
#
# Epoch 00011: val_acc improved from 0.87310 to 0.87620, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.011.h5
# Epoch 12/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3697 - acc: 0.8636 - val_loss: 0.3354 - val_acc: 0.8774
#
# Epoch 00012: val_acc improved from 0.87620 to 0.87740, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.012.h5
# Epoch 13/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3646 - acc: 0.8655 - val_loss: 0.3597 - val_acc: 0.8688
#
# Epoch 00013: val_acc did not improve from 0.87740
# Epoch 14/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3595 - acc: 0.8675 - val_loss: 0.3393 - val_acc: 0.8773
#
# Epoch 00014: val_acc did not improve from 0.87740
# Epoch 15/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3552 - acc: 0.8682 - val_loss: 0.3302 - val_acc: 0.8827
#
# Epoch 00015: val_acc improved from 0.87740 to 0.88270, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.015.h5
# Epoch 16/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3504 - acc: 0.8699 - val_loss: 0.3449 - val_acc: 0.8757
#
# Epoch 00016: val_acc did not improve from 0.88270
# Epoch 17/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3456 - acc: 0.8701 - val_loss: 0.3292 - val_acc: 0.8770
#
# Epoch 00017: val_acc did not improve from 0.88270
# Epoch 18/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3440 - acc: 0.8715 - val_loss: 0.3344 - val_acc: 0.8808
#
# Epoch 00018: val_acc did not improve from 0.88270
# Epoch 19/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3386 - acc: 0.8738 - val_loss: 0.3368 - val_acc: 0.8799
#
# Epoch 00019: val_acc did not improve from 0.88270
# Epoch 20/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3365 - acc: 0.8758 - val_loss: 0.3248 - val_acc: 0.8846
#
# Epoch 00020: val_acc improved from 0.88270 to 0.88460, saving model to /home/ryan-desktop/Documents/research-2019/fashion-mnist/saved_models/Fuzzy-LeNet_model.020.h5

# %%
plt.figure(figsize=(8,6))

ax1, = plt.plot(history.history["acc"], "g--")
ax2, = plt.plot(history.history["val_acc"], "g")
ax3, = plt.plot(fuzzy_history.history["acc"], "r--")
ax4, = plt.plot(fuzzy_history.history["val_acc"], "r")

plt.title("Fashion MNIST Accuracy")

plt.xlabel("Epoch")
plt.xticks([4, 9, 14, 19], [5, 10, 15, 20])

plt.ylabel("Accuracy")
plt.ylim(0.8, 0.9)

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["LeNet Training Set", 
     "LeNet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])

# %%
plt.figure(figsize=(8,6))

ax1, = plt.plot(history.history["loss"], "g--")
ax2, = plt.plot(history.history["val_loss"], "g")
ax3, = plt.plot(fuzzy_history.history["loss"], "r--")
ax4, = plt.plot(fuzzy_history.history["val_loss"], "r")

plt.title("Fashion MNIST Loss")

plt.xlabel("Epoch")
plt.xticks([4, 9, 14, 19], [5, 10, 15, 20])

plt.ylabel("Loss")

plt.legend(
    [ax1, ax2, ax3, ax4],
    ["LeNet Training Set", 
     "LeNet Validation Set",
     "DNFIS Training Set",
     "DNFIS Validation Set"])
